# %% [markdown]
# # Deliverabe 1: Retrieve Weather Data

# %%
# Import the dependencies.
import random
import pandas as pd
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Create a set of 2,000 random latitude and longitude combinations. Expanded size to generate more cities.
lats = np.random.uniform(low=-90.000, high=90.000, size=3500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=3500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 1099

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_city = city.title()
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mersing
# Processing Record 2 of Set 1 | iqaluit
# Processing Record 3 of Set 1 | coquimbo
# Processing Record 4 of Set 1 | moose factory
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 1 | roswell
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | verkhnevilyuysk
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | airai
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | warrnambool
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | nanhai
# Processing Record 18 of Set 1 | manggar
# Processing Record 19 of Set 1 | qiyang
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | khani
# Processing Record 22 of Set 1 | tromso
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | hamilton
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | hobyo
# Processing Record 27 of Set 1 | saldanha
# Processing Record 28 of Set 1 | katiola
# Processing Record 29 of Set 1 | sitia
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | bayan
# Processing Record 32 of Set 1 | vung tau
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | maura
# Processing Record 36 of Set 1 | provideniya
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | te anau
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | husavik
# Processing Record 42 of Set 1 | lata
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | shetpe
# Processing Record 45 of Set 1 | okhotsk
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | heinola
# Processing Record 49 of Set 1 | volga
# Processing Record 50 of Set 1 | basco
# Processing Record 1 of Set 2 | kavaratti
# Processing Record 2 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 2 | berkak
# Processing Record 4 of Set 2 | khatanga
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | san angelo
# Processing Record 7 of Set 2 | flinders
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | alice springs
# Processing Record 12 of Set 2 | oyama
# Processing Record 13 of Set 2 | tanete
# Processing Record 14 of Set 2 | okha
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | mayo
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | narsaq
# Processing Record 19 of Set 2 | shangzhi
# Processing Record 20 of Set 2 | saint-francois
# Processing Record 21 of Set 2 | broome
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | peniche
# Processing Record 24 of Set 2 | mwinilunga
# Processing Record 25 of Set 2 | chaman
# Processing Record 26 of Set 2 | cortez
# Processing Record 27 of Set 2 | znamenskoye
# Processing Record 28 of Set 2 | bambous virieux
# Processing Record 29 of Set 2 | huasahuasi
# Processing Record 30 of Set 2 | prince rupert
# Processing Record 31 of Set 2 | broken hill
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | banjar
# Processing Record 34 of Set 2 | dikson
# Processing Record 35 of Set 2 | laela
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | kargasok
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | lagoa
# Processing Record 40 of Set 2 | port alfred
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | manuk mangkaw
# Processing Record 43 of Set 2 | bulgan
# Processing Record 44 of Set 2 | padang
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | marystown
# Processing Record 48 of Set 2 | yongan
# Processing Record 49 of Set 2 | mitzic
# Processing Record 50 of Set 2 | victor harbor
# Processing Record 1 of Set 3 | preston
# Processing Record 2 of Set 3 | biak
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | plettenberg bay
# Processing Record 5 of Set 3 | hollola
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | ceres
# Processing Record 8 of Set 3 | phalaborwa
# Processing Record 9 of Set 3 | peruibe
# Processing Record 10 of Set 3 | cidreira
# Processing Record 11 of Set 3 | mlonggo
# Processing Record 12 of Set 3 | ahuimanu
# Processing Record 13 of Set 3 | ilulissat
# Processing Record 14 of Set 3 | vysokogornyy
# Processing Record 15 of Set 3 | havelock
# Processing Record 16 of Set 3 | bilma
# Processing Record 17 of Set 3 | nome
# Processing Record 18 of Set 3 | necochea
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | guangzhou
# Processing Record 21 of Set 3 | puerto salgar
# Processing Record 22 of Set 3 | roald
# Processing Record 23 of Set 3 | gat
# Processing Record 24 of Set 3 | ostrovnoy
# Processing Record 25 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | san quintin
# Processing Record 28 of Set 3 | sinnamary
# Processing Record 29 of Set 3 | port hedland
# Processing Record 30 of Set 3 | mareeba
# Processing Record 31 of Set 3 | vestmannaeyjar
# Processing Record 32 of Set 3 | khvalynsk
# Processing Record 33 of Set 3 | asfi
# Processing Record 34 of Set 3 | jinotega
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | olafsvik
# Processing Record 37 of Set 3 | treinta y tres
# Processing Record 38 of Set 3 | hilo
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 3 | valparaiso
# Processing Record 42 of Set 3 | cherskiy
# Processing Record 43 of Set 3 | hun
# Processing Record 44 of Set 3 | penzance
# Processing Record 45 of Set 3 | oksfjord
# Processing Record 46 of Set 3 | baculin
# Processing Record 47 of Set 3 | abnub
# Processing Record 48 of Set 3 | esperance
# Processing Record 49 of Set 3 | beyneu
# Processing Record 50 of Set 3 | stokmarknes
# Processing Record 1 of Set 4 | nyurba
# Processing Record 2 of Set 4 | ribeira grande
# Processing Record 3 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 4 | kagoro
# Processing Record 5 of Set 4 | coihaique
# Processing Record 6 of Set 4 | saint-pierre
# Processing Record 7 of Set 4 | kapaa
# Processing Record 8 of Set 4 | yaan
# Processing Record 9 of Set 4 | salalah
# Processing Record 10 of Set 4 | shelburne
# Processing Record 11 of Set 4 | bathsheba
# Processing Record 12 of Set 4 | altay
# Processing Record 13 of Set 4 | goma
# Processing Record 14 of Set 4 | vinica
# Processing Record 15 of Set 4 | jalu
# Processing Record 16 of Set 4 | batagay-alyta
# Processing Record 17 of Set 4 | puerto ayora
# Processing Record 18 of Set 4 | atambua
# Processing Record 19 of Set 4 | kodinsk
# Processing Record 20 of Set 4 | chapais
# Processing Record 21 of Set 4 | creel
# Processing Record 22 of Set 4 | buchanan
# Processing Record 23 of Set 4 | ketchikan
# Processing Record 24 of Set 4 | bentiu
# Processing Record 25 of Set 4 | hofn
# Processing Record 26 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 4 | abiy adi
# City not found. Skipping...
# Processing Record 28 of Set 4 | vredendal
# Processing Record 29 of Set 4 | faya
# Processing Record 30 of Set 4 | qasigiannguit
# Processing Record 31 of Set 4 | bonavista
# Processing Record 32 of Set 4 | dingle
# Processing Record 33 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 4 | igarka
# Processing Record 35 of Set 4 | aginskoye
# Processing Record 36 of Set 4 | ixtapa
# Processing Record 37 of Set 4 | springfield
# Processing Record 38 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 4 | nanakuli
# Processing Record 40 of Set 4 | east london
# Processing Record 41 of Set 4 | kalmunai
# Processing Record 42 of Set 4 | vila do maio
# Processing Record 43 of Set 4 | mogadishu
# Processing Record 44 of Set 4 | nata
# Processing Record 45 of Set 4 | rincon
# Processing Record 46 of Set 4 | tiksi
# Processing Record 47 of Set 4 | lebu
# Processing Record 48 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 4 | jardim
# Processing Record 1 of Set 5 | dunedin
# Processing Record 2 of Set 5 | kodiak
# Processing Record 3 of Set 5 | kiama
# Processing Record 4 of Set 5 | penukonda
# Processing Record 5 of Set 5 | nkowakowa
# Processing Record 6 of Set 5 | sorong
# Processing Record 7 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 5 | kupang
# Processing Record 9 of Set 5 | mnogovershinnyy
# Processing Record 10 of Set 5 | fort nelson
# Processing Record 11 of Set 5 | berlevag
# Processing Record 12 of Set 5 | bandarbeyla
# Processing Record 13 of Set 5 | kahului
# Processing Record 14 of Set 5 | georgetown
# Processing Record 15 of Set 5 | acapulco
# Processing Record 16 of Set 5 | san patricio
# Processing Record 17 of Set 5 | pisco
# Processing Record 18 of Set 5 | darhan
# Processing Record 19 of Set 5 | touros
# Processing Record 20 of Set 5 | bijie
# Processing Record 21 of Set 5 | marawi
# Processing Record 22 of Set 5 | sakhnovshchyna
# Processing Record 23 of Set 5 | cocobeach
# Processing Record 24 of Set 5 | faanui
# Processing Record 25 of Set 5 | dalby
# Processing Record 26 of Set 5 | sakakah
# Processing Record 27 of Set 5 | tamboril
# Processing Record 28 of Set 5 | katsuura
# Processing Record 29 of Set 5 | korla
# Processing Record 30 of Set 5 | san pietro in casale
# Processing Record 31 of Set 5 | ferme-neuve
# Processing Record 32 of Set 5 | mount isa
# Processing Record 33 of Set 5 | hovd
# Processing Record 34 of Set 5 | mar del plata
# Processing Record 35 of Set 5 | litoral del san juan
# City not found. Skipping...
# Processing Record 36 of Set 5 | severo-kurilsk
# Processing Record 37 of Set 5 | nortelandia
# Processing Record 38 of Set 5 | puerto escondido
# Processing Record 39 of Set 5 | turukhansk
# Processing Record 40 of Set 5 | kamenka
# Processing Record 41 of Set 5 | svetlogorsk
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | vasterhaninge
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | cassilandia
# Processing Record 46 of Set 5 | kruisfontein
# Processing Record 47 of Set 5 | shubarkuduk
# Processing Record 48 of Set 5 | naze
# Processing Record 49 of Set 5 | fairbanks
# Processing Record 50 of Set 5 | teya
# Processing Record 1 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 6 | monrovia
# Processing Record 3 of Set 6 | kulhudhuffushi
# Processing Record 4 of Set 6 | noumea
# Processing Record 5 of Set 6 | esso
# Processing Record 6 of Set 6 | amot
# Processing Record 7 of Set 6 | angra
# City not found. Skipping...
# Processing Record 8 of Set 6 | bilibino
# Processing Record 9 of Set 6 | port macquarie
# Processing Record 10 of Set 6 | luba
# Processing Record 11 of Set 6 | denpasar
# Processing Record 12 of Set 6 | port hardy
# Processing Record 13 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 6 | marv dasht
# City not found. Skipping...
# Processing Record 15 of Set 6 | nabire
# Processing Record 16 of Set 6 | clyde river
# Processing Record 17 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 6 | caravelas
# Processing Record 19 of Set 6 | adela
# Processing Record 20 of Set 6 | meulaboh
# Processing Record 21 of Set 6 | karratha
# Processing Record 22 of Set 6 | mount gambier
# Processing Record 23 of Set 6 | san joaquin
# Processing Record 24 of Set 6 | klaksvik
# Processing Record 25 of Set 6 | kawalu
# Processing Record 26 of Set 6 | sitka
# Processing Record 27 of Set 6 | sioux lookout
# Processing Record 28 of Set 6 | carnarvon
# Processing Record 29 of Set 6 | bardiyah
# Processing Record 30 of Set 6 | coahuayana
# Processing Record 31 of Set 6 | orocue
# Processing Record 32 of Set 6 | saint george
# Processing Record 33 of Set 6 | mizdah
# Processing Record 34 of Set 6 | san cristobal
# Processing Record 35 of Set 6 | pangnirtung
# Processing Record 36 of Set 6 | petropavlovskoye
# Processing Record 37 of Set 6 | nizwa
# Processing Record 38 of Set 6 | amapa
# Processing Record 39 of Set 6 | nishihara
# Processing Record 40 of Set 6 | borovskoy
# Processing Record 41 of Set 6 | pochutla
# Processing Record 42 of Set 6 | lensk
# Processing Record 43 of Set 6 | wageningen
# Processing Record 44 of Set 6 | andenes
# Processing Record 45 of Set 6 | hajduszovat
# Processing Record 46 of Set 6 | magadan
# Processing Record 47 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 6 | miyako
# Processing Record 49 of Set 6 | gabu
# Processing Record 50 of Set 6 | borujerd
# Processing Record 1 of Set 7 | felidhoo
# City not found. Skipping...
# Processing Record 2 of Set 7 | porosozero
# Processing Record 3 of Set 7 | obo
# Processing Record 4 of Set 7 | ewa beach
# Processing Record 5 of Set 7 | kitimat
# Processing Record 6 of Set 7 | sarakhs
# Processing Record 7 of Set 7 | guerrero negro
# Processing Record 8 of Set 7 | sambava
# Processing Record 9 of Set 7 | longyearbyen
# Processing Record 10 of Set 7 | tuatapere
# Processing Record 11 of Set 7 | ulladulla
# Processing Record 12 of Set 7 | garowe
# Processing Record 13 of Set 7 | samarai
# Processing Record 14 of Set 7 | jurm
# Processing Record 15 of Set 7 | khandyga
# Processing Record 16 of Set 7 | kalabo
# Processing Record 17 of Set 7 | asmar
# Processing Record 18 of Set 7 | ilam
# Processing Record 19 of Set 7 | isangel
# Processing Record 20 of Set 7 | penzberg
# Processing Record 21 of Set 7 | constitucion
# Processing Record 22 of Set 7 | pemba
# Processing Record 23 of Set 7 | suez
# Processing Record 24 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 7 | dharmavaram
# Processing Record 26 of Set 7 | thinadhoo
# Processing Record 27 of Set 7 | hokitika
# Processing Record 28 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 7 | haileybury
# Processing Record 30 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 7 | spring valley
# Processing Record 32 of Set 7 | sun valley
# Processing Record 33 of Set 7 | asau
# Processing Record 34 of Set 7 | wanaka
# Processing Record 35 of Set 7 | karlshamn
# Processing Record 36 of Set 7 | beipiao
# Processing Record 37 of Set 7 | orahovac
# Processing Record 38 of Set 7 | kavieng
# Processing Record 39 of Set 7 | batan
# Processing Record 40 of Set 7 | boyolangu
# Processing Record 41 of Set 7 | tazovskiy
# Processing Record 42 of Set 7 | neuquen
# Processing Record 43 of Set 7 | keti bandar
# Processing Record 44 of Set 7 | ancud
# Processing Record 45 of Set 7 | geraldton
# Processing Record 46 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 7 | zambezi
# Processing Record 48 of Set 7 | opuwo
# Processing Record 49 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 7 | andros town
# Processing Record 1 of Set 8 | hukuntsi
# Processing Record 2 of Set 8 | zhangye
# Processing Record 3 of Set 8 | mariel
# Processing Record 4 of Set 8 | vao
# Processing Record 5 of Set 8 | bonfim
# Processing Record 6 of Set 8 | teluk nibung
# Processing Record 7 of Set 8 | lasa
# Processing Record 8 of Set 8 | baruun-urt
# Processing Record 9 of Set 8 | marquette
# Processing Record 10 of Set 8 | salinopolis
# Processing Record 11 of Set 8 | hami
# Processing Record 12 of Set 8 | cabo san lucas
# Processing Record 13 of Set 8 | port blair
# Processing Record 14 of Set 8 | taoudenni
# Processing Record 15 of Set 8 | souillac
# Processing Record 16 of Set 8 | asuncion
# Processing Record 17 of Set 8 | siuna
# Processing Record 18 of Set 8 | palmer
# Processing Record 19 of Set 8 | kushima
# Processing Record 20 of Set 8 | jam sahib
# Processing Record 21 of Set 8 | nanortalik
# Processing Record 22 of Set 8 | lavrentiya
# Processing Record 23 of Set 8 | kaitangata
# Processing Record 24 of Set 8 | petropavlovka
# Processing Record 25 of Set 8 | etchojoa
# Processing Record 26 of Set 8 | maniitsoq
# Processing Record 27 of Set 8 | pinega
# Processing Record 28 of Set 8 | deniliquin
# Processing Record 29 of Set 8 | buraydah
# Processing Record 30 of Set 8 | ponta do sol
# Processing Record 31 of Set 8 | norman wells
# Processing Record 32 of Set 8 | middelburg
# Processing Record 33 of Set 8 | havoysund
# Processing Record 34 of Set 8 | rundu
# Processing Record 35 of Set 8 | itarema
# Processing Record 36 of Set 8 | saint cloud
# Processing Record 37 of Set 8 | ginir
# Processing Record 38 of Set 8 | luderitz
# Processing Record 39 of Set 8 | hurricane
# Processing Record 40 of Set 8 | qui nhon
# Processing Record 41 of Set 8 | shemordan
# Processing Record 42 of Set 8 | dakar
# Processing Record 43 of Set 8 | aporawan
# City not found. Skipping...
# Processing Record 44 of Set 8 | itaituba
# Processing Record 45 of Set 8 | sikea
# City not found. Skipping...
# Processing Record 46 of Set 8 | camacha
# Processing Record 47 of Set 8 | mao
# Processing Record 48 of Set 8 | tiznit
# Processing Record 49 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 50 of Set 8 | manjacaze
# Processing Record 1 of Set 9 | pitsunda
# Processing Record 2 of Set 9 | beloha
# Processing Record 3 of Set 9 | ambon
# Processing Record 4 of Set 9 | stephenville
# Processing Record 5 of Set 9 | zhigansk
# Processing Record 6 of Set 9 | luanda
# Processing Record 7 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 8 of Set 9 | vila franca do campo
# Processing Record 9 of Set 9 | pontianak
# Processing Record 10 of Set 9 | roma
# Processing Record 11 of Set 9 | scalea
# Processing Record 12 of Set 9 | eratinon
# City not found. Skipping...
# Processing Record 13 of Set 9 | pevek
# Processing Record 14 of Set 9 | parati
# Processing Record 15 of Set 9 | acarau
# Processing Record 16 of Set 9 | camacupa
# Processing Record 17 of Set 9 | port lincoln
# Processing Record 18 of Set 9 | talnakh
# Processing Record 19 of Set 9 | khadro
# Processing Record 20 of Set 9 | manzhouli
# Processing Record 21 of Set 9 | langxiang
# Processing Record 22 of Set 9 | rio gallegos
# Processing Record 23 of Set 9 | kamenskiy
# Processing Record 24 of Set 9 | marsala
# Processing Record 25 of Set 9 | aswan
# Processing Record 26 of Set 9 | tilichiki
# Processing Record 27 of Set 9 | kenai
# Processing Record 28 of Set 9 | porto-vecchio
# Processing Record 29 of Set 9 | balkanabat
# Processing Record 30 of Set 9 | ribas do rio pardo
# Processing Record 31 of Set 9 | cayenne
# Processing Record 32 of Set 9 | deputatskiy
# Processing Record 33 of Set 9 | cicevac
# Processing Record 34 of Set 9 | yarim
# Processing Record 35 of Set 9 | portland
# Processing Record 36 of Set 9 | klerksdorp
# Processing Record 37 of Set 9 | katobu
# Processing Record 38 of Set 9 | macamic
# Processing Record 39 of Set 9 | katherine
# Processing Record 40 of Set 9 | mandalgovi
# Processing Record 41 of Set 9 | dauphin
# Processing Record 42 of Set 9 | tura
# Processing Record 43 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 44 of Set 9 | kjollefjord
# Processing Record 45 of Set 9 | yulara
# Processing Record 46 of Set 9 | teruel
# Processing Record 47 of Set 9 | hudson bay
# Processing Record 48 of Set 9 | port elizabeth
# Processing Record 49 of Set 9 | alamosa
# Processing Record 50 of Set 9 | gazli
# Processing Record 1 of Set 10 | visby
# Processing Record 2 of Set 10 | aklavik
# Processing Record 3 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 10 | ziyamet
# City not found. Skipping...
# Processing Record 5 of Set 10 | banda aceh
# Processing Record 6 of Set 10 | nantucket
# Processing Record 7 of Set 10 | belmonte
# Processing Record 8 of Set 10 | yima
# Processing Record 9 of Set 10 | chanthaburi
# Processing Record 10 of Set 10 | lucea
# Processing Record 11 of Set 10 | kadoma
# Processing Record 12 of Set 10 | koboko
# Processing Record 13 of Set 10 | codrington
# Processing Record 14 of Set 10 | aquiraz
# Processing Record 15 of Set 10 | kano
# Processing Record 16 of Set 10 | tucupita
# Processing Record 17 of Set 10 | miquelon
# Processing Record 18 of Set 10 | avera
# Processing Record 19 of Set 10 | copiapo
# Processing Record 20 of Set 10 | el campo
# Processing Record 21 of Set 10 | chornobayivka
# Processing Record 22 of Set 10 | saldus
# Processing Record 23 of Set 10 | swansea
# Processing Record 24 of Set 10 | balabac
# Processing Record 25 of Set 10 | bollnas
# Processing Record 26 of Set 10 | bintulu
# Processing Record 27 of Set 10 | lakes entrance
# Processing Record 28 of Set 10 | nouadhibou
# Processing Record 29 of Set 10 | areado
# Processing Record 30 of Set 10 | ibra
# Processing Record 31 of Set 10 | yekepa
# Processing Record 32 of Set 10 | fatsa
# Processing Record 33 of Set 10 | diplo
# Processing Record 34 of Set 10 | myanaung
# Processing Record 35 of Set 10 | nago
# Processing Record 36 of Set 10 | manyana
# Processing Record 37 of Set 10 | teahupoo
# Processing Record 38 of Set 10 | pitimbu
# Processing Record 39 of Set 10 | yazman
# Processing Record 40 of Set 10 | haapiti
# Processing Record 41 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 10 | lazaro cardenas
# Processing Record 43 of Set 10 | uzumlu
# City not found. Skipping...
# Processing Record 44 of Set 10 | ypsilanti
# Processing Record 45 of Set 10 | mangaluru
# Processing Record 46 of Set 10 | nawa
# Processing Record 47 of Set 10 | skagen
# Processing Record 48 of Set 10 | grand forks
# Processing Record 49 of Set 10 | haines junction
# Processing Record 50 of Set 10 | odweyne
# Processing Record 1 of Set 11 | moindou
# Processing Record 2 of Set 11 | nemuro
# Processing Record 3 of Set 11 | currais novos
# Processing Record 4 of Set 11 | tabou
# Processing Record 5 of Set 11 | omboue
# Processing Record 6 of Set 11 | lompoc
# Processing Record 7 of Set 11 | barmer
# Processing Record 8 of Set 11 | arlit
# Processing Record 9 of Set 11 | doba
# Processing Record 10 of Set 11 | kolosovka
# Processing Record 11 of Set 11 | sorland
# Processing Record 12 of Set 11 | maningrida
# Processing Record 13 of Set 11 | derzhavinsk
# Processing Record 14 of Set 11 | ler
# Processing Record 15 of Set 11 | kardla
# Processing Record 16 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 11 | anloga
# Processing Record 18 of Set 11 | yangambi
# Processing Record 19 of Set 11 | iracoubo
# Processing Record 20 of Set 11 | danville
# Processing Record 21 of Set 11 | calinaoan
# City not found. Skipping...
# Processing Record 22 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 23 of Set 11 | yenagoa
# Processing Record 24 of Set 11 | puerto leguizamo
# Processing Record 25 of Set 11 | aykhal
# Processing Record 26 of Set 11 | sri aman
# Processing Record 27 of Set 11 | looc
# Processing Record 28 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 11 | dinguiraye
# Processing Record 30 of Set 11 | imeni poliny osipenko
# Processing Record 31 of Set 11 | college
# Processing Record 32 of Set 11 | tambacounda
# Processing Record 33 of Set 11 | cananeia
# Processing Record 34 of Set 11 | adrar
# Processing Record 35 of Set 11 | yingcheng
# Processing Record 36 of Set 11 | nizhnevartovsk
# Processing Record 37 of Set 11 | hasaki
# Processing Record 38 of Set 11 | lincoln
# Processing Record 39 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 11 | kirakira
# Processing Record 41 of Set 11 | pacifica
# Processing Record 42 of Set 11 | crotone
# Processing Record 43 of Set 11 | mogzon
# Processing Record 44 of Set 11 | maraa
# Processing Record 45 of Set 11 | dien bien
# City not found. Skipping...
# Processing Record 46 of Set 11 | cuamba
# Processing Record 47 of Set 11 | trofors
# Processing Record 48 of Set 11 | leningradskiy
# Processing Record 49 of Set 11 | kapoeta
# Processing Record 50 of Set 11 | sebastian
# Processing Record 1 of Set 12 | arman
# Processing Record 2 of Set 12 | micheweni
# Processing Record 3 of Set 12 | yumen
# Processing Record 4 of Set 12 | cao bang
# Processing Record 5 of Set 12 | skibbereen
# Processing Record 6 of Set 12 | gushikawa
# Processing Record 7 of Set 12 | arroyo grande
# Processing Record 8 of Set 12 | sao filipe
# Processing Record 9 of Set 12 | redcliffe
# Processing Record 10 of Set 12 | millinocket
# Processing Record 11 of Set 12 | fenelon falls
# Processing Record 12 of Set 12 | sulangan
# Processing Record 13 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 14 of Set 12 | beringovskiy
# Processing Record 15 of Set 12 | boguchany
# Processing Record 16 of Set 12 | vagur
# Processing Record 17 of Set 12 | sangar
# Processing Record 18 of Set 12 | diamantino
# Processing Record 19 of Set 12 | muros
# Processing Record 20 of Set 12 | ganganagar
# Processing Record 21 of Set 12 | oktyabrskiy
# Processing Record 22 of Set 12 | balykshi
# Processing Record 23 of Set 12 | concepcion del oro
# Processing Record 24 of Set 12 | caibarien
# Processing Record 25 of Set 12 | nioro
# Processing Record 26 of Set 12 | pimenta bueno
# Processing Record 27 of Set 12 | cap malheureux
# Processing Record 28 of Set 12 | inirida
# Processing Record 29 of Set 12 | saint-augustin
# Processing Record 30 of Set 12 | winnemucca
# Processing Record 31 of Set 12 | carballo
# Processing Record 32 of Set 12 | umm lajj
# Processing Record 33 of Set 12 | shimoda
# Processing Record 34 of Set 12 | santa rosa
# Processing Record 35 of Set 12 | xiongyue
# Processing Record 36 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 12 | dolores hidalgo
# Processing Record 38 of Set 12 | abu zabad
# Processing Record 39 of Set 12 | kalkar
# Processing Record 40 of Set 12 | point pleasant
# Processing Record 41 of Set 12 | vostok
# Processing Record 42 of Set 12 | tual
# Processing Record 43 of Set 12 | kompaniyivka
# Processing Record 44 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 12 | zyryanka
# Processing Record 46 of Set 12 | gumdag
# Processing Record 47 of Set 12 | kalemie
# Processing Record 48 of Set 12 | asyut
# Processing Record 49 of Set 12 | krasnoselkup
# Processing Record 50 of Set 12 | lar
# Processing Record 1 of Set 13 | popova
# Processing Record 2 of Set 13 | san andres
# Processing Record 3 of Set 13 | nalut
# Processing Record 4 of Set 13 | mirnyy
# Processing Record 5 of Set 13 | karasburg
# Processing Record 6 of Set 13 | el terrero
# Processing Record 7 of Set 13 | shu
# Processing Record 8 of Set 13 | talaya
# Processing Record 9 of Set 13 | muroto
# Processing Record 10 of Set 13 | yatou
# Processing Record 11 of Set 13 | moussoro
# Processing Record 12 of Set 13 | sur
# Processing Record 13 of Set 13 | marsabit
# Processing Record 14 of Set 13 | road town
# Processing Record 15 of Set 13 | whitehorse
# Processing Record 16 of Set 13 | lafia
# Processing Record 17 of Set 13 | berasia
# Processing Record 18 of Set 13 | srednekolymsk
# Processing Record 19 of Set 13 | pustoshka
# Processing Record 20 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 13 | soanierana ivongo
# Processing Record 22 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 13 | lillehammer
# Processing Record 24 of Set 13 | sidi ali
# Processing Record 25 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 26 of Set 13 | zhangjiakou
# Processing Record 27 of Set 13 | brae
# Processing Record 28 of Set 13 | oranjemund
# Processing Record 29 of Set 13 | puerto madryn
# Processing Record 30 of Set 13 | yinchuan
# Processing Record 31 of Set 13 | presidencia roque saenz pena
# Processing Record 32 of Set 13 | ust-nera
# Processing Record 33 of Set 13 | calama
# Processing Record 34 of Set 13 | garoua
# Processing Record 35 of Set 13 | grindavik
# Processing Record 36 of Set 13 | spearfish
# Processing Record 37 of Set 13 | gweta
# Processing Record 38 of Set 13 | mirabad
# Processing Record 39 of Set 13 | ambilobe
# Processing Record 40 of Set 13 | dubbo
# Processing Record 41 of Set 13 | urengoy
# Processing Record 42 of Set 13 | yamada
# Processing Record 43 of Set 13 | kushiro
# Processing Record 44 of Set 13 | oistins
# Processing Record 45 of Set 13 | sungaipenuh
# Processing Record 46 of Set 13 | ban nahin
# Processing Record 47 of Set 13 | piranhas
# Processing Record 48 of Set 13 | kutum
# Processing Record 49 of Set 13 | formosa do rio preto
# Processing Record 50 of Set 13 | sao joao da barra
# Processing Record 1 of Set 14 | oranjestad
# Processing Record 2 of Set 14 | sola
# Processing Record 3 of Set 14 | cockburn town
# Processing Record 4 of Set 14 | ube
# Processing Record 5 of Set 14 | kachiry
# Processing Record 6 of Set 14 | awbari
# Processing Record 7 of Set 14 | rawson
# Processing Record 8 of Set 14 | pundaguitan
# Processing Record 9 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 10 of Set 14 | rosarito
# Processing Record 11 of Set 14 | yanam
# Processing Record 12 of Set 14 | slave lake
# Processing Record 13 of Set 14 | bahia blanca
# Processing Record 14 of Set 14 | bubaque
# Processing Record 15 of Set 14 | abha
# Processing Record 16 of Set 14 | tessalit
# Processing Record 17 of Set 14 | saint anthony
# Processing Record 18 of Set 14 | fayaoue
# Processing Record 19 of Set 14 | uberaba
# Processing Record 20 of Set 14 | kapit
# Processing Record 21 of Set 14 | mamlyutka
# Processing Record 22 of Set 14 | strezhevoy
# Processing Record 23 of Set 14 | port moresby
# Processing Record 24 of Set 14 | prince albert
# Processing Record 25 of Set 14 | corozal
# Processing Record 26 of Set 14 | morondava
# Processing Record 27 of Set 14 | shenjiamen
# Processing Record 28 of Set 14 | litovko
# Processing Record 29 of Set 14 | acajutla
# Processing Record 30 of Set 14 | vila
# Processing Record 31 of Set 14 | goryachegorsk
# Processing Record 32 of Set 14 | cairns
# Processing Record 33 of Set 14 | jacareacanga
# Processing Record 34 of Set 14 | sam chuk
# Processing Record 35 of Set 14 | abalak
# Processing Record 36 of Set 14 | acari
# Processing Record 37 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 38 of Set 14 | paamiut
# Processing Record 39 of Set 14 | nizhnyaya tavda
# Processing Record 40 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 14 | macae
# Processing Record 42 of Set 14 | sakaiminato
# Processing Record 43 of Set 14 | atyrau
# Processing Record 44 of Set 14 | dubovskoye
# Processing Record 45 of Set 14 | bawku
# Processing Record 46 of Set 14 | westport
# Processing Record 47 of Set 14 | seybaplaya
# Processing Record 48 of Set 14 | tombouctou
# Processing Record 49 of Set 14 | nelson bay
# Processing Record 50 of Set 14 | niquero
# Processing Record 1 of Set 15 | smithers
# Processing Record 2 of Set 15 | nanchong
# Processing Record 3 of Set 15 | moryakovskiy zaton
# Processing Record 4 of Set 15 | dawei
# Processing Record 5 of Set 15 | zvishavane
# Processing Record 6 of Set 15 | bara
# Processing Record 7 of Set 15 | teknaf
# Processing Record 8 of Set 15 | huarmey
# Processing Record 9 of Set 15 | peleduy
# Processing Record 10 of Set 15 | maihar
# Processing Record 11 of Set 15 | tel aviv-yafo
# Processing Record 12 of Set 15 | caxito
# Processing Record 13 of Set 15 | eydhafushi
# Processing Record 14 of Set 15 | hoquiam
# Processing Record 15 of Set 15 | huntington
# Processing Record 16 of Set 15 | zheleznogorsk-ilimskiy
# Processing Record 17 of Set 15 | mosetse
# Processing Record 18 of Set 15 | soc trang
# Processing Record 19 of Set 15 | acatic
# Processing Record 20 of Set 15 | vila velha
# Processing Record 21 of Set 15 | champerico
# Processing Record 22 of Set 15 | iranshahr
# Processing Record 23 of Set 15 | phan thiet
# Processing Record 24 of Set 15 | leopold
# Processing Record 25 of Set 15 | raga
# Processing Record 26 of Set 15 | collie
# Processing Record 27 of Set 15 | fuerte olimpo
# Processing Record 28 of Set 15 | santa rosalia
# Processing Record 29 of Set 15 | chinsali
# Processing Record 30 of Set 15 | bijar
# Processing Record 31 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 15 | maku
# Processing Record 33 of Set 15 | eureka
# Processing Record 34 of Set 15 | lakatoro
# Processing Record 35 of Set 15 | ruteng
# Processing Record 36 of Set 15 | charters towers
# Processing Record 37 of Set 15 | inhambane
# Processing Record 38 of Set 15 | hualmay
# Processing Record 39 of Set 15 | hambantota
# Processing Record 40 of Set 15 | porto nacional
# Processing Record 41 of Set 15 | yuncheng
# Processing Record 42 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 15 | chadiza
# Processing Record 44 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 45 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 15 | vuktyl
# Processing Record 47 of Set 15 | duz
# City not found. Skipping...
# Processing Record 48 of Set 15 | brookings
# Processing Record 49 of Set 15 | mucurapo
# Processing Record 50 of Set 15 | miraflores
# Processing Record 1 of Set 16 | gazanjyk
# Processing Record 2 of Set 16 | marienburg
# Processing Record 3 of Set 16 | yei
# Processing Record 4 of Set 16 | tlahualilo
# City not found. Skipping...
# Processing Record 5 of Set 16 | puerto carreno
# Processing Record 6 of Set 16 | bondo
# Processing Record 7 of Set 16 | yeniseysk
# Processing Record 8 of Set 16 | azar shahr
# City not found. Skipping...
# Processing Record 9 of Set 16 | adelaide
# Processing Record 10 of Set 16 | sao jose da coroa grande
# Processing Record 11 of Set 16 | akdepe
# Processing Record 12 of Set 16 | puerto plata
# Processing Record 13 of Set 16 | ocala
# Processing Record 14 of Set 16 | vangaindrano
# Processing Record 15 of Set 16 | olga
# Processing Record 16 of Set 16 | darnah
# Processing Record 17 of Set 16 | gorontalo
# Processing Record 18 of Set 16 | udachnyy
# Processing Record 19 of Set 16 | lillooet
# Processing Record 20 of Set 16 | gutad
# Processing Record 21 of Set 16 | anadyr
# Processing Record 22 of Set 16 | laiyang
# Processing Record 23 of Set 16 | dodoma
# Processing Record 24 of Set 16 | skjaerhollen
# City not found. Skipping...
# Processing Record 25 of Set 16 | los llanos de aridane
# Processing Record 26 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 16 | zunyi
# Processing Record 28 of Set 16 | gombong
# Processing Record 29 of Set 16 | proletarsk
# Processing Record 30 of Set 16 | iralaya
# Processing Record 31 of Set 16 | san isidro
# Processing Record 32 of Set 16 | porto novo
# Processing Record 33 of Set 16 | labuhan
# Processing Record 34 of Set 16 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 16 | vardo
# Processing Record 36 of Set 16 | dehloran
# Processing Record 37 of Set 16 | soyo
# Processing Record 38 of Set 16 | durango
# Processing Record 39 of Set 16 | talakan
# Processing Record 40 of Set 16 | sabang
# Processing Record 41 of Set 16 | inuvik
# Processing Record 42 of Set 16 | gorin
# Processing Record 43 of Set 16 | ushtobe
# Processing Record 44 of Set 16 | klyuchi
# Processing Record 45 of Set 16 | christchurch
# Processing Record 46 of Set 16 | seidu
# Processing Record 47 of Set 16 | andapa
# Processing Record 48 of Set 16 | nakonde
# Processing Record 49 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 16 | goderich
# Processing Record 1 of Set 17 | zhanaozen
# Processing Record 2 of Set 17 | rocha
# Processing Record 3 of Set 17 | chabahar
# Processing Record 4 of Set 17 | walvis bay
# Processing Record 5 of Set 17 | viseu
# Processing Record 6 of Set 17 | waingapu
# Processing Record 7 of Set 17 | caconda
# Processing Record 8 of Set 17 | logansport
# Processing Record 9 of Set 17 | lac du bonnet
# Processing Record 10 of Set 17 | zaysan
# Processing Record 11 of Set 17 | zakamensk
# Processing Record 12 of Set 17 | iglesias
# Processing Record 13 of Set 17 | rubtsovsk
# Processing Record 14 of Set 17 | tucumcari
# Processing Record 15 of Set 17 | yelahanka
# Processing Record 16 of Set 17 | palmerston
# Processing Record 17 of Set 17 | matara
# Processing Record 18 of Set 17 | abakaliki
# Processing Record 19 of Set 17 | arawa
# Processing Record 20 of Set 17 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 17 | mana
# Processing Record 22 of Set 17 | nuuk
# Processing Record 23 of Set 17 | shieli
# Processing Record 24 of Set 17 | awjilah
# Processing Record 25 of Set 17 | manokwari
# Processing Record 26 of Set 17 | zachagansk
# City not found. Skipping...
# Processing Record 27 of Set 17 | santa cruz cabralia
# Processing Record 28 of Set 17 | kutahya
# Processing Record 29 of Set 17 | takoradi
# Processing Record 30 of Set 17 | kuusamo
# Processing Record 31 of Set 17 | marabba
# Processing Record 32 of Set 17 | newport
# Processing Record 33 of Set 17 | nhulunbuy
# Processing Record 34 of Set 17 | matadi
# Processing Record 35 of Set 17 | kayseri
# Processing Record 36 of Set 17 | yingzhong
# City not found. Skipping...
# Processing Record 37 of Set 17 | minnedosa
# Processing Record 38 of Set 17 | ust-omchug
# Processing Record 39 of Set 17 | glarus
# Processing Record 40 of Set 17 | bagdarin
# Processing Record 41 of Set 17 | bella vista
# Processing Record 42 of Set 17 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 17 | ellisras
# Processing Record 44 of Set 17 | seydisehir
# Processing Record 45 of Set 17 | hinesville
# Processing Record 46 of Set 17 | sinjar
# Processing Record 47 of Set 17 | saravan
# Processing Record 48 of Set 17 | saquarema
# Processing Record 49 of Set 17 | phalombe
# Processing Record 50 of Set 17 | kafue
# Processing Record 1 of Set 18 | bugene
# Processing Record 2 of Set 18 | bullhead city
# Processing Record 3 of Set 18 | richards bay
# Processing Record 4 of Set 18 | suntar
# Processing Record 5 of Set 18 | severo-yeniseyskiy
# Processing Record 6 of Set 18 | darab
# Processing Record 7 of Set 18 | kedgwick
# Processing Record 8 of Set 18 | union
# Processing Record 9 of Set 18 | dali
# Processing Record 10 of Set 18 | anito
# Processing Record 11 of Set 18 | hargeysa
# Processing Record 12 of Set 18 | egvekinot
# Processing Record 13 of Set 18 | chokwe
# Processing Record 14 of Set 18 | jujuy
# City not found. Skipping...
# Processing Record 15 of Set 18 | lima
# Processing Record 16 of Set 18 | inongo
# Processing Record 17 of Set 18 | mujiayingzi
# Processing Record 18 of Set 18 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 18 | rawah
# Processing Record 20 of Set 18 | skjervoy
# Processing Record 21 of Set 18 | zaragoza
# Processing Record 22 of Set 18 | margate
# Processing Record 23 of Set 18 | buala
# Processing Record 24 of Set 18 | buchen
# Processing Record 25 of Set 18 | ingham
# Processing Record 26 of Set 18 | carbonia
# Processing Record 27 of Set 18 | vanavara
# Processing Record 28 of Set 18 | flin flon
# Processing Record 29 of Set 18 | rio claro
# Processing Record 30 of Set 18 | talcahuano
# Processing Record 31 of Set 18 | rudersdorf
# Processing Record 32 of Set 18 | pierre
# Processing Record 33 of Set 18 | yueyang
# Processing Record 34 of Set 18 | marfino
# Processing Record 35 of Set 18 | tongchuan
# Processing Record 36 of Set 18 | half moon bay
# Processing Record 37 of Set 18 | isla mujeres
# Processing Record 38 of Set 18 | nara
# Processing Record 39 of Set 18 | agadir
# Processing Record 40 of Set 18 | puerto lleras
# Processing Record 41 of Set 18 | dandong
# Processing Record 42 of Set 18 | wentzville
# Processing Record 43 of Set 18 | kuching
# Processing Record 44 of Set 18 | wajir
# Processing Record 45 of Set 18 | port augusta
# Processing Record 46 of Set 18 | illapel
# Processing Record 47 of Set 18 | san carlos de bariloche
# Processing Record 48 of Set 18 | dukat
# Processing Record 49 of Set 18 | srandakan
# Processing Record 50 of Set 18 | oron
# Processing Record 1 of Set 19 | high rock
# Processing Record 2 of Set 19 | selma
# Processing Record 3 of Set 19 | male
# Processing Record 4 of Set 19 | ojinaga
# Processing Record 5 of Set 19 | kalevala
# Processing Record 6 of Set 19 | tshane
# Processing Record 7 of Set 19 | salihorsk
# Processing Record 8 of Set 19 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 19 | kieta
# Processing Record 10 of Set 19 | puerto narino
# Processing Record 11 of Set 19 | kralendijk
# Processing Record 12 of Set 19 | apricena
# Processing Record 13 of Set 19 | amahai
# Processing Record 14 of Set 19 | bourail
# Processing Record 15 of Set 19 | timaru
# Processing Record 16 of Set 19 | grand gaube
# Processing Record 17 of Set 19 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 19 | mayor pablo lagerenza
# Processing Record 19 of Set 19 | cabedelo
# Processing Record 20 of Set 19 | djibo
# Processing Record 21 of Set 19 | ust-kulom
# Processing Record 22 of Set 19 | muriti
# Processing Record 23 of Set 19 | keshan
# City not found. Skipping...
# Processing Record 24 of Set 19 | labuan
# Processing Record 25 of Set 19 | sobolevo
# Processing Record 26 of Set 19 | veraval
# Processing Record 27 of Set 19 | alcudia
# Processing Record 28 of Set 19 | erdenet
# Processing Record 29 of Set 19 | mitsamiouli
# Processing Record 30 of Set 19 | alofi
# Processing Record 31 of Set 19 | ahipara
# Processing Record 32 of Set 19 | bangassou
# Processing Record 33 of Set 19 | polunochnoye
# Processing Record 34 of Set 19 | port keats
# Processing Record 35 of Set 19 | sao felix do xingu
# Processing Record 36 of Set 19 | komsomolskiy
# Processing Record 37 of Set 19 | koumac
# Processing Record 38 of Set 19 | baturite
# Processing Record 39 of Set 19 | luau
# Processing Record 40 of Set 19 | carutapera
# Processing Record 41 of Set 19 | zile
# Processing Record 42 of Set 19 | timizart
# Processing Record 43 of Set 19 | northam
# Processing Record 44 of Set 19 | bereda
# Processing Record 45 of Set 19 | burgeo
# Processing Record 46 of Set 19 | galgani
# City not found. Skipping...
# Processing Record 47 of Set 19 | gondar
# Processing Record 48 of Set 19 | ksenyevka
# City not found. Skipping...
# Processing Record 49 of Set 19 | jaguaribe
# Processing Record 50 of Set 19 | mombetsu
# Processing Record 1 of Set 20 | junction city
# Processing Record 2 of Set 20 | diego de almagro
# Processing Record 3 of Set 20 | port-gentil
# Processing Record 4 of Set 20 | qaqortoq
# Processing Record 5 of Set 20 | ongandjera
# Processing Record 6 of Set 20 | ajdabiya
# Processing Record 7 of Set 20 | santa lucia
# Processing Record 8 of Set 20 | san jose
# Processing Record 9 of Set 20 | poum
# Processing Record 10 of Set 20 | forrest city
# Processing Record 11 of Set 20 | ulaanbaatar
# Processing Record 12 of Set 20 | maridi
# Processing Record 13 of Set 20 | usolye-sibirskoye
# Processing Record 14 of Set 20 | meadow lake
# Processing Record 15 of Set 20 | kabarnet
# Processing Record 16 of Set 20 | visnes
# Processing Record 17 of Set 20 | santo domingo
# Processing Record 18 of Set 20 | knysna
# Processing Record 19 of Set 20 | kilindoni
# Processing Record 20 of Set 20 | pacific grove
# Processing Record 21 of Set 20 | luwuk
# Processing Record 22 of Set 20 | varnavino
# Processing Record 23 of Set 20 | lagunas
# Processing Record 24 of Set 20 | ygatimi
# Processing Record 25 of Set 20 | tepalcatepec
# Processing Record 26 of Set 20 | shepsi
# Processing Record 27 of Set 20 | telde
# Processing Record 28 of Set 20 | turtkul
# City not found. Skipping...
# Processing Record 29 of Set 20 | krasnogorsk
# Processing Record 30 of Set 20 | aripuana
# Processing Record 31 of Set 20 | liepaja
# Processing Record 32 of Set 20 | tsienyane
# City not found. Skipping...
# Processing Record 33 of Set 20 | qujing
# Processing Record 34 of Set 20 | ozernovskiy
# Processing Record 35 of Set 20 | show low
# Processing Record 36 of Set 20 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 20 | kindu
# Processing Record 38 of Set 20 | russell
# Processing Record 39 of Set 20 | kitgum
# Processing Record 40 of Set 20 | ossora
# Processing Record 41 of Set 20 | yanchukan
# City not found. Skipping...
# Processing Record 42 of Set 20 | terney
# Processing Record 43 of Set 20 | garden city
# Processing Record 44 of Set 20 | shingu
# Processing Record 45 of Set 20 | jabiru
# City not found. Skipping...
# Processing Record 46 of Set 20 | villarrubia de los ojos
# Processing Record 47 of Set 20 | coruripe
# Processing Record 48 of Set 20 | rodrigues alves
# Processing Record 49 of Set 20 | lorengau
# Processing Record 50 of Set 20 | neya
# Processing Record 1 of Set 21 | vanimo
# Processing Record 2 of Set 21 | ostersund
# Processing Record 3 of Set 21 | tocopilla
# Processing Record 4 of Set 21 | creston
# Processing Record 5 of Set 21 | kumphawapi
# Processing Record 6 of Set 21 | tam ky
# Processing Record 7 of Set 21 | aksha
# Processing Record 8 of Set 21 | imbituba
# Processing Record 9 of Set 21 | smirnykh
# Processing Record 10 of Set 21 | ati
# Processing Record 11 of Set 21 | scarborough
# Processing Record 12 of Set 21 | kota kinabalu
# Processing Record 13 of Set 21 | wuxi
# Processing Record 14 of Set 21 | bennettsville
# Processing Record 15 of Set 21 | majene
# Processing Record 16 of Set 21 | ende
# Processing Record 17 of Set 21 | susanville
# Processing Record 18 of Set 21 | okahandja
# Processing Record 19 of Set 21 | poronaysk
# Processing Record 20 of Set 21 | nordhausen
# Processing Record 21 of Set 21 | araouane
# Processing Record 22 of Set 21 | meilu
# City not found. Skipping...
# Processing Record 23 of Set 21 | borogontsy
# Processing Record 24 of Set 21 | suicheng
# Processing Record 25 of Set 21 | moron
# Processing Record 26 of Set 21 | barcelona
# Processing Record 27 of Set 21 | piuma
# Processing Record 28 of Set 21 | osypenko
# Processing Record 29 of Set 21 | kaniama
# Processing Record 30 of Set 21 | garcia
# Processing Record 31 of Set 21 | budacu de jos
# Processing Record 32 of Set 21 | balikpapan
# Processing Record 33 of Set 21 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 21 | dobryatino
# Processing Record 35 of Set 21 | wajima
# Processing Record 36 of Set 21 | horta
# Processing Record 37 of Set 21 | merauke
# Processing Record 38 of Set 21 | viking
# Processing Record 39 of Set 21 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 21 | makakilo city
# Processing Record 41 of Set 21 | tautira
# Processing Record 42 of Set 21 | dauriya
# Processing Record 43 of Set 21 | bambanglipuro
# Processing Record 44 of Set 21 | ambulu
# Processing Record 45 of Set 21 | mailsi
# Processing Record 46 of Set 21 | weligama
# Processing Record 47 of Set 21 | aden
# Processing Record 48 of Set 21 | harper
# Processing Record 49 of Set 21 | xiaoweizhai
# Processing Record 50 of Set 21 | baracoa
# Processing Record 1 of Set 22 | elat
# Processing Record 2 of Set 22 | albert lea
# Processing Record 3 of Set 22 | timra
# Processing Record 4 of Set 22 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 5 of Set 22 | jatibonico
# Processing Record 6 of Set 22 | gamba
# Processing Record 7 of Set 22 | ordzhonikidze
# Processing Record 8 of Set 22 | kununurra
# Processing Record 9 of Set 22 | dong hoi
# Processing Record 10 of Set 22 | neiafu
# Processing Record 11 of Set 22 | fallon
# Processing Record 12 of Set 22 | talara
# Processing Record 13 of Set 22 | banon
# Processing Record 14 of Set 22 | moyale
# Processing Record 15 of Set 22 | ye
# City not found. Skipping...
# Processing Record 16 of Set 22 | laguna de perlas
# Processing Record 17 of Set 22 | sechura
# Processing Record 18 of Set 22 | wolfurt
# Processing Record 19 of Set 22 | zhucheng
# Processing Record 20 of Set 22 | pravia
# Processing Record 21 of Set 22 | la romana
# Processing Record 22 of Set 22 | afmadu
# City not found. Skipping...
# Processing Record 23 of Set 22 | letham
# Processing Record 24 of Set 22 | de aar
# Processing Record 25 of Set 22 | padilla
# Processing Record 26 of Set 22 | matamoros
# Processing Record 27 of Set 22 | ngunguru
# Processing Record 28 of Set 22 | salym
# Processing Record 29 of Set 22 | wonthaggi
# Processing Record 30 of Set 22 | kolokani
# Processing Record 31 of Set 22 | waipawa
# Processing Record 32 of Set 22 | santa cruz de tenerife
# Processing Record 33 of Set 22 | okakarara
# Processing Record 34 of Set 22 | la ronge
# Processing Record 35 of Set 22 | zolotinka
# City not found. Skipping...
# Processing Record 36 of Set 22 | bredy
# Processing Record 37 of Set 22 | aksarayskiy
# Processing Record 38 of Set 22 | kangaatsiaq
# Processing Record 39 of Set 22 | kabalo
# Processing Record 40 of Set 22 | casper
# Processing Record 41 of Set 22 | radom
# Processing Record 42 of Set 22 | oum hadjer
# Processing Record 43 of Set 22 | la plata
# Processing Record 44 of Set 22 | cazaje
# City not found. Skipping...
# Processing Record 45 of Set 22 | sagvag
# Processing Record 46 of Set 22 | kargil
# Processing Record 47 of Set 22 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 22 | tongzi
# Processing Record 49 of Set 22 | lasem
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Mersing      MY   2.4312  103.8405     78.51        87          55
# 1          Iqaluit      CA  63.7506  -68.5145     -0.31        64          71
# 2         Coquimbo      CL -29.9533  -71.3436     58.95        82           6
# 3    Moose Factory      CA  51.2585  -80.6094     22.98        70          66
# 4            Bluff      NZ -46.6000  168.3333     55.80        73           7
# 5          Roswell      US  34.0232  -84.3616     72.09        68          99
# 6     Punta Arenas      CL -53.1500  -70.9167     46.11        93         100
# 7       Butaritari      KI   3.0707  172.7902     81.77        74          12
# 8  Verkhnevilyuysk      RU  63.4453  120.3167     32.11        98         100
# 9            Vaini      TO -21.2000 -175.2000     81.32        79          97
#
#    Wind Speed Current Description
# 0        3.13       moderate rain
# 1       11.01       broken clouds
# 2        2.51           clear sky
# 3        6.76       broken clouds
# 4        7.34           clear sky
# 5        1.70     overcast clouds
# 6        3.20          light rain
# 7       11.81          few clouds
# 8        7.27          light snow
# 9       13.31     overcast clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
